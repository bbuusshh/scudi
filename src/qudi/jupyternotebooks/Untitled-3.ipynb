# %%
from matplotlib import pyplot as plt
from qudi.util.fit_models import autocorrelation
import numpy as np
from scipy.optimize import curve_fit

# %%
data = timetaggerlogic.corr_data[0], timetaggerlogic.corr_data[1]

# %%
popt, pcov = curve_fit(autocorrelation.g2_three_level_system, np.array(data[0]), np.array(data[1]))

# %%
plt.plot(np.array(data[0]),np.array(data[1]))

# %%
popt
# Out:
# array([  0.93416635,   0.36322356,   0.99933127,   1.00077611,
#        326.6512816 ])

# %%
def g2_three_level_system(x, offset, center, gamma_1, gamma_2, beta):
    #https://arxiv.org/ftp/arxiv/papers/1708/1708.04523.pdf page 18
    return ((1 + offset) - (1 + beta) * np.exp( - np.abs(x - center) * gamma_1) + beta * np.exp( - np.abs(x - center) * gamma_2))

# %%
plt.plot(np.array(data[0]),np.array(data[1]))
plt.plot(np.array(data[0]),g2_three_level_system(np.array(data[0]),
*[0, 0, 50000000, 2, 0.02]),
 'g-')

# %%
t = np.linspace(-5e-7, 5e-7, 1000)
plt.plot(t,autocorrelation.g2_three_level_system(t,
*[0, 0, 50000000, 0.005, 2]),
 'g-')
